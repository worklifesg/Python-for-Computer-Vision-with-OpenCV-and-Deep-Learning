# %% [markdown]
# <a href="https://colab.research.google.com/github/worklifesg/Python-for-Computer-Vision-with-OpenCV-and-Deep-Learning/blob/main/3.%20Image%20Processing/1_ImageProcessing_ColorSpaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Image Processing
#
# In this section we will discuss image processing techniques that can be later implemented and used in Object Detection and Tracking
#
#  - IP operations
#  - Perform IP operations such as Smoothing, Blurring, Morphological, Operations
#  - IP properties such as color spaces and histograms
# ---
#
# ##### 1. Color Spaces
#
#  - We worked with RGB which is very commonly used. In 1970s, <b> HSL (hue,saturation, lightness) and HSV (hue, saturation, value)</b> color models were used.
#  - HSL/HSV are more closely aligned with the way human vision actually perceives color.
#
# How HSL/HSV are different from RGB
#
# - RGB can be though of 3D cube with three dimensions of Red, Green and Blue.
# - HSL can be thought as a cylinder model where:
#   - <b> Hue: around the cylinder different colors
#   - Saturation: how much huw you end up having
#   - Lightness: how dark (bottom of cylinder - black) or light (top of cylinder - white) </b>
# - HSV can be also thought as a cylinder model like HSL where:
#   - <b> Hue: around the cylinder different colors
#   - Saturation: how much hue you end up having
#   - Value: white is at the top center only

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('00-puppy.jpg')
plt.imshow(img)

# %%
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img2 = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img2)

# %%
img3 = cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
plt.imshow(img3)
